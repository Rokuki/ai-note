# %%
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 转灰度
img1 = cv2.imread('./img/cat.jpg')  
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# %%
#keypoints
sift = cv2.xfeatures2d.SIFT_create()
keypoints_1, descriptors_1 = sift.detectAndCompute(img1,None)
print('keypoints_1', keypoints_1[55].pt)
print('descriptors_1', descriptors_1)
# Out:
# keypoints_1 (194.7465057373047, 533.4154663085938)
# descriptors_1 [[ 0.  0.  2. ...  0.  0.  6.]
#  [ 7.  1.  0. ...  0.  0.  2.]
#  [ 0.  0.  0. ...  0.  0.  1.]
#  ...
#  [ 6.  1.  0. ...  0.  0.  5.]
#  [ 0.  0.  0. ...  0.  0.  7.]
#  [ 2.  0.  0. ...  0.  0. 14.]]

# %%
img_1 = cv2.drawKeypoints(gray1,keypoints_1,img1)
plt.figure(figsize = (10,12))
plt.imshow(img_1,interpolation='nearest', aspect='auto')
